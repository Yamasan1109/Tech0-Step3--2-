# %%
#<udaさん>
#最低限必要な情報:物件名・住所・間取り・家賃・階数
#検索エリア：23区の2K以上の物件、管理費込みで家賃22万円未満

#<自分>
# 1.SUUMOのwebページを取得して解析する.対象は、自分の家の周辺（新宮、古賀、福間）で、JR鹿児島本線に近いところ
# page={} としておく。後々ループ文を作る

# %%
# ライブラリのインポート
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %% [markdown]
# ①　まずは1件目のデータリストを作る

# %%
#<自分>
# 1.SUUMOのwebページを取得して解析する.対象は、自分の家の周辺（新宮、古賀、福間）で、JR鹿児島本線に近いところ
# page={} としておく。後々ループ文を作る
base_url = "https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=090&bs=040&ra=040&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&ek=702033730&ek=702024150&ek=702014510&ek=702042610&ek=702042620&ek=702023900&rn=7020&page={}"
# 各ページのURLを作成
target_url = base_url.format(1)
print(target_url)
# Out:
# https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=090&bs=040&ra=040&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&ek=702033730&ek=702024150&ek=702014510&ek=702042610&ek=702042620&ek=702023900&rn=7020&page=1

# %%
#target_urlへのアクセス結果を、変数responseに格納
response = requests.get(target_url)
# 取得結果を解析してsoupに格納
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# cassetteitemクラスを持つdivタグを全て取得
property_elements = soup.find_all('div', class_='cassetteitem')
len(property_elements)
# Out:
# 30

# %%
#変数property_elementにproperty_elementsの最初の要素を格納する
property_element= property_elements[0]
print(property_element)
# Out:
# <div class="cassetteitem">
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸アパート</span></div>
# <div class="cassetteitem_content-title">ＪＲ鹿児島本線 千鳥駅 2階建 築11年</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">福岡県古賀市花見東７</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ鹿児島本線/千鳥駅 歩8分</div>
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ鹿児島本線/古賀駅 歩21分</div>
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ鹿児島本線/福間駅 歩24分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築11年</div>
# <div>2階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cassetteitem-item">
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100352750462"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_5o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.1万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">5.1万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100352750462">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000086276975/?bc=100352750462" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a><button class="js-kobetsuShiryoSeikyu cassetteitem_other-inquiry_button" type="button">
# 												お問い合わせ
# 													<span class="cassetteitem_other-inquiry_text">(無料)</span>
# </button>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100319737076"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s6o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.2万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">-</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100319737076">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000069999228/?bc=100319737076" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a><button class="js-kobetsuShiryoSeikyu cassetteitem_other-inquiry_button" type="button">
# 												お問い合わせ
# 													<span class="cassetteitem_other-inquiry_text">(無料)</span>
# </button>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>

# %%
# 物件・建物情報を取得し、変数property_detailに格納する
property_detail = property_element.find('div', class_="cassetteitem-detail")
# 各部屋の情報を取得し、変数property_tableに格納する
property_table = property_element.find('table',class_="cassetteitem_other")

# %%
print(property_detail)
# Out:
# <div class="cassetteitem-detail">
# <div class="cassetteitem-detail-object">
# <div class="cassetteitem_object">
# <div class="cassetteitem_object-item">
# <img alt="" class="js-noContextMenu js-linkImage js-scrollLazy js-adjustImg" height="0" rel="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_gw.jpg" src="...%3D%3D" width="0">
# </img></div>
# </div>
# </div>
# <div class="cassetteitem-detail-body">
# <div class="cassetteitem_content">
# <div class="cassetteitem_content-label"><span class="ui-pct ui-pct--util1">賃貸アパート</span></div>
# <div class="cassetteitem_content-title">ＪＲ鹿児島本線 千鳥駅 2階建 築11年</div>
# <div class="cassetteitem_content-body">
# <ul class="cassetteitem_detail">
# <li class="cassetteitem_detail-col1">福岡県古賀市花見東７</li>
# <li class="cassetteitem_detail-col2">
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ鹿児島本線/千鳥駅 歩8分</div>
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ鹿児島本線/古賀駅 歩21分</div>
# <div class="cassetteitem_detail-text" style="font-weight:bold">ＪＲ鹿児島本線/福間駅 歩24分</div>
# </li>
# <li class="cassetteitem_detail-col3">
# <div>築11年</div>
# <div>2階建</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>

# %%
print(property_table)
# Out:
# <table class="cassetteitem_other">
# <thead>
# <tr>
# <th class="cassetteitem_other-col01"> </th>
# <th class="cassetteitem_other-col02"> </th>
# <th class="cassetteitem_other-col03">階</th>
# <th class="cassetteitem_other-col04">賃料/管理費</th>
# <th class="cassetteitem_other-col05">敷金/礼金</th>
# <th class="cassetteitem_other-col06">間取り/専有面積</th>
# <th class="cassetteitem_other-col07"> </th>
# <th class="cassetteitem_other-col08">お気に入り</th>
# <th class="cassetteitem_other-col09"> </th>
# </tr>
# </thead>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100352750462"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_5o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.1万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">5.1万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100352750462">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000086276975/?bc=100352750462" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a><button class="js-kobetsuShiryoSeikyu cassetteitem_other-inquiry_button" type="button">
# 												お問い合わせ
# 													<span class="cassetteitem_other-inquiry_text">(無料)</span>
# </button>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100319737076"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_s6o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/076/100319737076/100319737076_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.2万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">-</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100319737076">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000069999228/?bc=100319737076" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a><button class="js-kobetsuShiryoSeikyu cassetteitem_other-inquiry_button" type="button">
# 												お問い合わせ
# 													<span class="cassetteitem_other-inquiry_text">(無料)</span>
# </button>
# </td>
# </tr>
# </tbody>
# </table>

# %%
# 物件名を取得し、変数titleに格納する ※strip()関数…両端にある特定の文字列や空白文字を削除するメソッド
title = property_detail.find('div', class_="cassetteitem_content-title").text.strip()
# 住所を取得し、変数addressに格納する
address = property_detail.find('li', class_="cassetteitem_detail-col1").text.strip()
# アクセス情報を取得し、変数accessに格納する
access = property_detail.find('li', class_="cassetteitem_detail-col2").text.strip()
# 築年数を取得し、変数ageに格納する
age = property_detail.find("li", class_="cassetteitem_detail-col3").text.strip()
# 部屋情報のブロックから、各部屋情報を取得する
room_elements = property_table.find_all('tr', class_="js-cassette_link")

# %%
title, address, access, age
# Out:
# ('ＪＲ鹿児島本線 千鳥駅 2階建 築11年',
#  '福岡県古賀市花見東７',
#  'ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅 歩24分',
#  '築11年\n2階建')

# %%
#変数property_tableからすべてのtrタグを取得して、変数room_elements（部屋の構成要素）に格納
room_elements = property_table.find_all('tr', class_="js-cassette_link")

#room_elementsの中から最初の一つだけroom_elementに格納
room_element = room_elements[0]

# %%
print(room_element)
# Out:
# <tr class="js-cassette_link">
# <td class="cassetteitem_other-checkbox js-cassetteitem_checkbox">
# <input class="js-ikkatsuCB js-single_checkbox" id="bukken_0" name="bc" type="checkbox" value="100352750462"/><label for="bc"> </label>
# </td>
# <td>
# <div class="casssetteitem_other-thumbnail js-view_gallery_images js-noContextMenu" data-imgs="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_go.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_co.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_ro.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_8o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_9o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_7o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_10o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_11o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s2o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s3o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s5o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s1o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s4o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_s6o.jpg,https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_5o.jpg">
# <img alt="" class="casssetteitem_other-thumbnail-img casssetteitem_other-thumbnail-img--hasimages js-view_gallery-modal js-scrollLazy" rel="https://img01.suumo.com/front/gazo/fr/bukken/462/100352750462/100352750462_co.jpg" src="...%3D%3D"/>
# <span class="cassetteitem_other-thumbnail-expansion js-view_gallery-modal"></span>
# </div>
# </td>
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.1万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">5.1万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>
# </ul>
# </td>
# <td>
# <ul class="cassetteitem-taglist">
# </ul>
# </td>
# <td class="js-property">
# <input class="js-clipkey" type="hidden" value="100352750462">
# <a class="ui-btn ui-favorite cassette_favorite cassette_favorite--sm js-addMyList js-linkSuppresser" href="javascript:void(0);">
# <span class="ui-favorite-icon cassette_favorite-icon"><span class="fr_list-eachicon fr_list-eachicon--favorite"></span></span>
# <span class="ui-favorite-text">追加</span>
# <span class="ui-favorite-icon_add cassette_favorite-icon_add"><span class="fr_list-eachicon fr_list-eachicon--favorite_add"></span></span>
# <span class="ui-favorite-text_add">追加</span>
# </a>
# </input></td>
# <td class="ui-text--midium ui-text--bold">
# <a class="js-cassette_link_href cassetteitem_other-linktext" href="/chintai/jnc_000086276975/?bc=100352750462" onclick="sendBeaconSiteCatalystClick(event,this,'click_casset_bkn_link',false);" target="_blank">詳細を見る</a><button class="js-kobetsuShiryoSeikyu cassetteitem_other-inquiry_button" type="button">
# 												お問い合わせ
# 													<span class="cassetteitem_other-inquiry_text">(無料)</span>
# </button>
# </td>
# </tr>

# %%
#9つのtrタグの中で、欲しい情報は、3番目~6番目※[2:6]最初の数字は0からカウント、次は1からカウント、即ち3番目から6番目を意味する
floor, price, first_fee, capacity = room_element.find_all('td')[2:6]

# %%
print(floor)
print(price)
print(first_fee)
print(capacity)
# Out:
# <td>
# 											1階</td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.1万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">5.1万円</span></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>
# </ul>
# </td>

# %%
# floor以外の部分は、更にふたつの<li>タグに分かれているから、更に細かい情報の抽出を行う
# price:「賃料」と「管理費」、first_fee:「敷金」と「礼金」、capacity:「間取り」と「専有面積」
fee, management_fee = price.find_all('li')
deposit, gratuity = first_fee.find_all('li')
floor_plan, area =capacity.find_all('li')

# %%
print(fee)
print(management_fee)
print(deposit)
print(gratuity)
print(floor_plan)
print(area)
# Out:
# <li><span class="cassetteitem_price cassetteitem_price--rent"><span class="cassetteitem_other-emphasis ui-text--bold">5.1万円</span></span></li>
# <li><span class="cassetteitem_price cassetteitem_price--administration">3000円</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--deposit">-</span></li>
# <li><span class="cassetteitem_price cassetteitem_price--gratuity">5.1万円</span></li>
# <li><span class="cassetteitem_madori">1LDK</span></li>
# <li><span class="cassetteitem_menseki">35.18m<sup>2</sup></span></li>

# %%
# 取得した情報を辞書に格納する※property:資産、財産、
property_data = {
'title': title, # 物件名
'address': address, #住所
'access': access, # アクセス情報
'age': age, #築年数
'floor': floor.text.strip(), # 階数
'fee': fee.text.strip(), #家賃
'management_fee' : management_fee.text.strip(), #管理費
'deposit': deposit.text.strip(), #敷金
'gratuity': gratuity.text.strip(), #礼金
'floor_plan': floor_plan.text.strip(), #間取り
'area': area.text.strip() #面積
}

# %%
property_data
# Out:
# {'title': 'ＪＲ鹿児島本線 千鳥駅 2階建 築11年',
#  'address': '福岡県古賀市花見東７',
#  'access': 'ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅 歩24分',
#  'age': '築11年\n2階建',
#  'floor': '1階',
#  'fee': '5.1万円',
#  'management_fee': '3000円',
#  'deposit': '-',
#  'gratuity': '5.1万円',
#  'floor_plan': '1LDK',
#  'area': '35.18m2'}

# %% [markdown]
# 1件目のデータが取得できた！

# %% [markdown]
# ② forループ処理で全てのデータを取得していく

# %%
#URLを設定
base_url= "https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=090&bs=040&ra=040&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&ek=702033730&ek=702024150&ek=702014510&ek=702042610&ek=702042620&ek=702023900&rn=7020&page={}"

#初期ページへのリクエストを送信して総ページ数を取得する
response = requests.get(base_url.format(1))
#取得したHTMLを'BeautifulSoup'で解析する
soup_total_page = BeautifulSoup(response.text, 'html.parser')

#最後のPage数を取得する. ol class='pagination-parts'の中の最後の文字（※[-1]は最後を意味する）を数字に変換したものを、total_pageに入れる
total_page = int(soup_total_page.find('ol', class_='pagination-parts').find_all('li')[-1].text)
print(total_page)

#データ収集用リスト
data_list = []
# Out:
# 36

# %%
# 各ページをループ処理.
for page in range(1,total_page+1):
    # 各ページのURLを作成
    target_url = base_url.format(page)
    #target_urlへのアクセス結果を、変数responseに格納
    response = requests.get(target_url)
    #負荷を軽減するために1秒スリープ
    time.sleep(1)
    #現在のページ数と最終ページ数を表示
    print(f"ページ{page}/{total_page}の情報を取得中｡｡｡")
    # ステータスコードが200（正常）以外の場合、ループを終了
    if response.status_code != 200:
        print(f"ページ{page}の取得が終了しました。")
        break
    # 取得結果を解析してsoupに格納
    soup = BeautifulSoup(response.text, 'html.parser')
    # cassetteitemクラスを持つdivタグを全て取得
    property_elements = soup.find_all('div', class_='cassetteitem')
    # 各部屋情報をforループで取得する
    for property_element in property_elements:
        # 物件・建物情報を取得し、変数property_detailに格納する
        property_detail = property_element.find('div', class_="cassetteitem-detail")
        # 各部屋の情報を取得し、変数property_tableに格納する
        property_table = property_element.find('table',class_="cassetteitem_other")
        # 物件名を取得し、変数titleに格納する ※strip()関数…両端にある特定の文字列や空白文字を削除するメソッド
        title = property_detail.find('div', class_="cassetteitem_content-title").text.strip()
        # 住所を取得し、変数addressに格納する
        address = property_detail.find('li', class_="cassetteitem_detail-col1").text.strip()
        # アクセス情報を取得し、変数accessに格納する
        access = property_detail.find('li', class_="cassetteitem_detail-col2").text.strip()
        # 築年数を取得し、変数ageに格納する
        age = property_detail.find("li", class_="cassetteitem_detail-col3").text.strip()
        # 部屋情報のブロックから、各部屋情報を取得する
        room_elements = property_table.find_all('tr', class_="js-cassette_link")
        # 各部屋情報をforループで取得する
        for room_element in room_elements:
            # 部屋情報の行から、必要な情報を取得する.※[2:6]最初の数字は0からカウント、次は1からカウント、即ち3番目から6番目を意味する
            floor, price, first_fee, capacity = room_element.find_all('td')[2:6]
            #更に細かい情報を取得する
            #fee:賃料、management_fee:管理費、deposit:敷金、gratuity:管理費、floor_plan:間取り、area:専有面積
            fee, management_fee = price.find_all('li')
            deposit, gratuity = first_fee.find_all('li')
            floor_plan, area =capacity.find_all('li')
            #　取得した情報を辞書に格納する
            property_data = {
                'title': title, # 物件名
                'address': address, #住所
                'access': access, # アクセス情報
                'age': age, #築年数
                'floor': floor.text.strip(), # 階数
                'fee': fee.text.strip(), #家賃
                'management_fee' : management_fee.text.strip(), #管理費
                'deposit': deposit.text.strip(), #敷金
                'gratuity': gratuity.text.strip(), #礼金
                'floor_plan': floor_plan.text.strip(), #間取り
                'area': area.text.strip() #面積
            }
            # 取得した辞書をリストに追加する.取得した辞書をd_listに格納する. 各部屋情報をd_listに格納できるようになった
            data_list.append(property_data)

#data_listの大きさを確認
print('data_listの大きさ', len(data_list))

# データフレームの作成
property_df = pd.DataFrame(data_list)
# Out:
# ページ1/36の情報を取得中｡｡｡
# ページ2/36の情報を取得中｡｡｡
# ページ3/36の情報を取得中｡｡｡
# ページ4/36の情報を取得中｡｡｡
# ページ5/36の情報を取得中｡｡｡
# ページ6/36の情報を取得中｡｡｡
# ページ7/36の情報を取得中｡｡｡
# ページ8/36の情報を取得中｡｡｡
# ページ9/36の情報を取得中｡｡｡
# ページ10/36の情報を取得中｡｡｡
# ページ11/36の情報を取得中｡｡｡
# ページ12/36の情報を取得中｡｡｡
# ページ13/36の情報を取得中｡｡｡
# ページ14/36の情報を取得中｡｡｡
# ページ15/36の情報を取得中｡｡｡
# ページ16/36の情報を取得中｡｡｡
# ページ17/36の情報を取得中｡｡｡
# ページ18/36の情報を取得中｡｡｡
# ページ19/36の情報を取得中｡｡｡
# ページ20/36の情報を取得中｡｡｡
# ページ21/36の情報を取得中｡｡｡
# ページ22/36の情報を取得中｡｡｡
# ページ23/36の情報を取得中｡｡｡
# ページ24/36の情報を取得中｡｡｡
# ページ25/36の情報を取得中｡｡｡
# ページ26/36の情報を取得中｡｡｡
# ページ27/36の情報を取得中｡｡｡
# ページ28/36の情報を取得中｡｡｡
# ページ29/36の情報を取得中｡｡｡
# ページ30/36の情報を取得中｡｡｡
# ページ31/36の情報を取得中｡｡｡
# ページ32/36の情報を取得中｡｡｡
# ページ33/36の情報を取得中｡｡｡
# ページ34/36の情報を取得中｡｡｡
# ページ35/36の情報を取得中｡｡｡
# ページ36/36の情報を取得中｡｡｡
# data_listの大きさ 1677

# %%
# d_listの中身を確認する。[-1]で最終ページを示す
data_list[0]
# Out:
# {'title': 'ＪＲ鹿児島本線 千鳥駅 2階建 築11年',
#  'address': '福岡県古賀市花見東７',
#  'access': 'ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅 歩24分',
#  'age': '築11年\n2階建',
#  'floor': '1階',
#  'fee': '5.1万円',
#  'management_fee': '3000円',
#  'deposit': '-',
#  'gratuity': '5.1万円',
#  'floor_plan': '1LDK',
#  'area': '35.18m2'}

# %%
data_list[-1]
# Out:
# {'title': '博寿アパート',
#  'address': '福岡県福岡市東区唐原５',
#  'access': 'ＪＲ鹿児島本線/九産大前駅 歩7分\nＪＲ鹿児島本線/福工大前駅 バス10分 (バス停)唐の原 歩8分\nＪＲ鹿児島本線/千早駅 バス15分 (バス停)唐の原 歩8分',
#  'age': '築41年\n2階建',
#  'floor': '2階',
#  'fee': '1.8万円',
#  'management_fee': '-',
#  'deposit': '-',
#  'gratuity': '-',
#  'floor_plan': 'ワンルーム',
#  'area': '18m2'}

# %% [markdown]
# 【確認結果OK】最初と最初の物件確認済

# %%
# SUUMO_data.csv　に落とす
property_df.to_csv('suumo_data.csv')

# %%
property_df.head()
# Out:
#                     title         address  \
# 0    ＪＲ鹿児島本線 千鳥駅 2階建 築11年      福岡県古賀市花見東７
# 1    ＪＲ鹿児島本線 千鳥駅 2階建 築11年      福岡県古賀市花見東７
# 2    ＪＲ鹿児島本線 ししぶ駅 2階建 築9年       福岡県古賀市日吉２
# 3  ＪＲ鹿児島本線 新宮中央駅 3階建 築11年  福岡県糟屋郡新宮町中央駅前１
# 4              メール　ド　コレール       福岡県古賀市日吉２
#
#                                               access        age floor    fee  \
# 0  ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅...  築11年\n2階建    1階  5.1万円
# 1  ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅...  築11年\n2階建    1階  5.2万円
# 2  ＪＲ鹿児島本線/ししぶ駅 歩5分\nＪＲ鹿児島本線/古賀駅 歩16分\nＪＲ鹿児島本線/新宮...   築9年\n2階建    2階  5.2万円
# 3  ＪＲ鹿児島本線/新宮中央駅 歩5分\nＪＲ鹿児島本線/ししぶ駅 歩20分\nＪＲ鹿児島本線/...  築11年\n3階建    3階  6.9万円
# 4  ＪＲ鹿児島本線/ししぶ駅 歩6分\nＪＲ鹿児島本線/古賀駅 歩19分\nＪＲ鹿児島本線/新宮...  築12年\n2階建    2階  5.6万円
#
#   management_fee deposit gratuity floor_plan     area
# 0          3000円       -    5.1万円       1LDK  35.18m2
# 1          3000円       -        -       1LDK  35.18m2
# 2          3500円       -    7.8万円       1LDK  31.73m2
# 3          4000円       -   13.8万円       1LDK   45.4m2
# 4          3300円       -    5.6万円       1LDK  46.09m2

# %% [markdown]
# ③データ加工

# %%
import pandas as pd
import re

# csvファイルを読み込む
df = pd.read_csv('suumo_data.csv', index_col=None, encoding='utf-8-sig')

# %%
# データフレームを作成
df = pd.DataFrame(property_df)

#データの整形
# "万円"を削除して、文字列を数値に変換する関数定義
def convert_rent(value):
    if isinstance(value, str)and '万円' in value:
        return float(value.replace('万円', ''))
    else:
        return value
    
# "円"を削除して、文字列を数値に変換する関数定義
def convert_deposit(value):
    if isinstance(value, str)and '円' in value:
        return float(value.replace('円', ''))
    else:
        return value
    
df['fee'] = df['fee'].apply(convert_rent) #家賃：fee
df['deposit'] = df['deposit'].apply(convert_rent) #敷金　deposit
df['gratuity'] = df['gratuity'].apply(convert_rent) #礼金　gratuity(チップ)
df['management_fee'] = df['management_fee'].apply(convert_deposit) #management_fee

# age列の処理: 築年数のみを抽出し、新築の場合は0に設定
df['age'] = df['age'].apply(lambda x: 0 if '新築' in x else int(re.search(r'築(\d+)年', x).group(1)))

# 重複する行を削除 名称：title,アドレス：address,階数：floor,家賃：fee,敷金：deposit,礼金：gratuity,間取り：floor_plan
unique_data = df.drop_duplicates(subset=['title', 'address', 'floor', 'fee', 'deposit', 'gratuity', 'floor_plan'])

# 重複のないデータ件数を取得
len(unique_data)
# Out:
# 1443

# %%
# 元のデータ件数を表示
len(data_list)
# Out:
# 1677

# %%
# CSVに出力
csv_file_path = 'unique_output.csv'
unique_data.to_csv(csv_file_path, index=False)

print(f"CSVファイルが出力されました: {csv_file_path}")

unique_data
# Out:
# CSVファイルが出力されました: unique_output.csv
#                        title         address  \
# 0       ＪＲ鹿児島本線 千鳥駅 2階建 築11年      福岡県古賀市花見東７
# 1       ＪＲ鹿児島本線 千鳥駅 2階建 築11年      福岡県古賀市花見東７
# 2       ＪＲ鹿児島本線 ししぶ駅 2階建 築9年       福岡県古賀市日吉２
# 3     ＪＲ鹿児島本線 新宮中央駅 3階建 築11年  福岡県糟屋郡新宮町中央駅前１
# 4                 メール　ド　コレール       福岡県古賀市日吉２
# ...                      ...             ...
# 1672      ＪＲ香椎線 和白駅 2階建 築34年    福岡県福岡市東区和白丘２
# 1673                      サン     福岡県福岡市東区唐原６
# 1674      ＪＲ香椎線 和白駅 2階建 築42年    福岡県福岡市東区和白丘２
# 1675                 メルサハイツA     福岡県福岡市東区和白４
# 1676                  博寿アパート     福岡県福岡市東区唐原５
#
#                                                  access  age floor  fee  \
# 0     ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅...   11    1階  5.1
# 1     ＪＲ鹿児島本線/千鳥駅 歩8分\nＪＲ鹿児島本線/古賀駅 歩21分\nＪＲ鹿児島本線/福間駅...   11    1階  5.2
# 2     ＪＲ鹿児島本線/ししぶ駅 歩5分\nＪＲ鹿児島本線/古賀駅 歩16分\nＪＲ鹿児島本線/新宮...    9    2階  5.2
# 3     ＪＲ鹿児島本線/新宮中央駅 歩5分\nＪＲ鹿児島本線/ししぶ駅 歩20分\nＪＲ鹿児島本線/...   11    3階  6.9
# 4     ＪＲ鹿児島本線/ししぶ駅 歩6分\nＪＲ鹿児島本線/古賀駅 歩19分\nＪＲ鹿児島本線/新宮...   12    2階  5.6
# ...                                                 ...  ...   ...  ...
# 1672  ＪＲ香椎線/和白駅 歩14分\nＪＲ鹿児島本線/福工大前駅 歩15分\n西鉄貝塚線/三苫駅 ...   34    1階  2.0
# 1673  ＪＲ鹿児島本線/九産大前駅 歩12分\nＪＲ鹿児島本線/香椎駅 バス5分 (バス停)唐の原 ...   37    2階  1.7
# 1674  ＪＲ香椎線/和白駅 歩7分\nＪＲ鹿児島本線/福工大前駅 バス10分 (バス停)上和白郵便局...   42    2階  1.9
# 1675  ＪＲ香椎線/和白駅 歩9分\n西鉄貝塚線/唐の原駅 歩5分\nＪＲ鹿児島本線/福工大前駅 バ...   40    2階  1.6
# 1676  ＪＲ鹿児島本線/九産大前駅 歩7分\nＪＲ鹿児島本線/福工大前駅 バス10分 (バス停)唐の...   41    2階  1.8
#
#      management_fee deposit gratuity floor_plan     area
# 0            3000.0       -      5.1       1LDK  35.18m2
# 1            3000.0       -        -       1LDK  35.18m2
# 2            3500.0       -      7.8       1LDK  31.73m2
# 3            4000.0       -     13.8       1LDK   45.4m2
# 4            3300.0       -      5.6       1LDK  46.09m2
# ...             ...     ...      ...        ...      ...
# 1672              -       -        -      ワンルーム     18m2
# 1673         3000.0       -        -         1K     20m2
# 1674         2000.0       -      1.9         1K  21.44m2
# 1675         3500.0       -        -      ワンルーム     19m2
# 1676              -       -        -      ワンルーム     18m2
#
# [1443 rows x 11 columns]
